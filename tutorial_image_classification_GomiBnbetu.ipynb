# %% [markdown]
# <a href="https://colab.research.google.com/github/RyosukeHara/AI_Kenshu/blob/main/tutorial_image_classification_GomiBnbetu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 画像分類実践
#
# (colab) ページ上部の ランタイム → ランタイムのタイプを変更 → ハードウェアアクセラレータを「GPU」に変更 → 保存
# 深層学習では、簡単な計算を大量に行い学習を進めます。こういった計算にはGPUが適しています。
#
# [参考資料](https://aiacademy.jp/texts/show/?id=164)

# %% [markdown]
# ### パッケージの準備

# %%
# 必要なパッケージをインストール
# !から始まる行はshell command (Pythonではない)
# !pip install icrawler

# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting icrawler
#   Downloading icrawler-0.6.6-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from icrawler) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from icrawler) (4.9.2)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from icrawler) (2.27.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from icrawler) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from icrawler) (8.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->icrawler) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (3.4)
# Installing collected packages: icrawler
# Successfully installed icrawler-0.6.6

# %% [markdown]
# ### webから画像をかき集める：クローリング
#
# 今回は猫・犬の画像分類器を作成します。猫と犬の画像が必要なので、webからかき集めてきます。収集した画像はランタイムのディスク領域に保存されるため、ランタイムのセッションを閉じると削除されます。
#
# *クローリングの結果は毎回変わるため、この方法では再現性は得られません

# %%
from icrawler.builtin import BingImageCrawler
import logging

n_img = 200
class1_name = "tape_paper"
class1_keyword = "ガムテープ　紙製"
class2_name = "tape_fabric"
class2_keyword = "ガムテープ　布製"
class3_name = "tape_vinyl"
class3_keyword = "ガムテープ　ビニール製"

# 猫の画像を取得
crawler = BingImageCrawler(storage={"root_dir": class1_name}, log_level=logging.INFO, parser_threads=2, downloader_threads=4,)
crawler.crawl(keyword=class1_keyword, max_num=n_img)  # 検索キーワードはひらがなの方がちゃんと動物が出る可能性が高い気がする

# 犬の画像を取得
crawler = BingImageCrawler(storage={"root_dir": class2_name}, log_level=logging.INFO, parser_threads=2, downloader_threads=4,)
crawler.crawl(keyword=class2_keyword, max_num=n_img)

# うさぎの画像を取得
crawler = BingImageCrawler(storage={"root_dir": class3_name}, log_level=logging.INFO, parser_threads=2, downloader_threads=4,)
crawler.crawl(keyword=class3_keyword, max_num=n_img)

# ダウンロード用のzipファイル生成
# !zip -r $class1_name $class1_name
# !zip -r $class2_name $class2_name
# !zip -r $class3_name $class3_name
# Out:
# ERROR:downloader:Response status code 403, file https://realestate-pctr.c.yimg.jp/d/realestate-magazine-tools/2020/02/28/98ecda9aabaed67b33ac523ca514cddd8bd9c554.jpg
# ERROR:downloader:Response status code 403, file https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0304/users/9d560070d9ce0c08058e8608550ac45d8b907abe/i-img1200x900-1650792701u2vahg491971.jpg
# ERROR:downloader:Exception caught when downloading file https://www.gazaihanbai.jp/upload/save_image/07031456_5596240d83f8b.jpg, error: HTTPSConnectionPool(host='www.gazaihanbai.jp', port=443): Max retries exceeded with url: /upload/save_image/07031456_5596240d83f8b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)'))), remaining retry times: 2
# ERROR:downloader:Response status code 404, file https://shop.r10s.jp/tokyu-hands/cabinet/55/00/4967529521255-2.jpg
# ERROR:downloader:Exception caught when downloading file https://www.gazaihanbai.jp/upload/save_image/07031456_5596240d83f8b.jpg, error: HTTPSConnectionPool(host='www.gazaihanbai.jp', port=443): Max retries exceeded with url: /upload/save_image/07031456_5596240d83f8b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)'))), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://www.gazaihanbai.jp/upload/save_image/07031456_5596240d83f8b.jpg, error: HTTPSConnectionPool(host='www.gazaihanbai.jp', port=443): Max retries exceeded with url: /upload/save_image/07031456_5596240d83f8b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)'))), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0791.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0791.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f08036acb50>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/1278048_s-320x240.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/1278048_s-320x240.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f080365b820>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0785-940x705.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0785-940x705.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f080365bd00>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0792-640x480.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0792-640x480.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f081e235ea0>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0791.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0791.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f08036acf70>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/1278048_s-320x240.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/1278048_s-320x240.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f08037ede70>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0785-940x705.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0785-940x705.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f08037ee320>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0792-640x480.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0792-640x480.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0803777910>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0791.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0791.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f08037ee8c0>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Response status code 403, file https://shopping.geocities.jp/wrappingclub1/wrapping/cabinet/mt/maste-main.jpg
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/1278048_s-320x240.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/1278048_s-320x240.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f080365b3a0>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0785-940x705.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0785-940x705.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0803736f50>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0792-640x480.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0792-640x480.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f08036ac070>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0788-640x480.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0788-640x480.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f081c198e50>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0788-640x480.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0788-640x480.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f081e2357b0>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://yukawanet.com/wp-content/uploads/2020/06/DSC_0788-640x480.jpg, error: HTTPSConnectionPool(host='yukawanet.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/06/DSC_0788-640x480.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f080365bc40>, 'Connection to yukawanet.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/1262519_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/9319977_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/8858735_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/U447947_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/650103_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/1985683_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/9466927_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/8513002_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/L1/J479056_l1.jpg
# WARNING:urllib3.connection:Certificate did not match expected hostname: hamao333333.2style.net. Certificate: {'subject': ((('commonName', 's8.gungunboo.com'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '03A23639827CCCC1A3DDECE146201E6608A5', 'notBefore': 'Apr 11 00:04:14 2023 GMT', 'notAfter': 'Jul 10 00:04:13 2023 GMT', 'subjectAltName': (('DNS', 's8.gungunboo.com'),), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# ERROR:downloader:Exception caught when downloading file https://hamao333333.2style.net/img/img_0281.jpg, error: HTTPSConnectionPool(host='hamao333333.2style.net', port=443): Max retries exceeded with url: /img/img_0281.jpg (Caused by SSLError(CertificateError("hostname 'hamao333333.2style.net' doesn't match 's8.gungunboo.com'"))), remaining retry times: 2
# WARNING:urllib3.connection:Certificate did not match expected hostname: hamao333333.2style.net. Certificate: {'subject': ((('commonName', 's8.gungunboo.com'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '03A23639827CCCC1A3DDECE146201E6608A5', 'notBefore': 'Apr 11 00:04:14 2023 GMT', 'notAfter': 'Jul 10 00:04:13 2023 GMT', 'subjectAltName': (('DNS', 's8.gungunboo.com'),), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# ERROR:downloader:Exception caught when downloading file https://hamao333333.2style.net/img/img_0281.jpg, error: HTTPSConnectionPool(host='hamao333333.2style.net', port=443): Max retries exceeded with url: /img/img_0281.jpg (Caused by SSLError(CertificateError("hostname 'hamao333333.2style.net' doesn't match 's8.gungunboo.com'"))), remaining retry times: 1
# WARNING:urllib3.connection:Certificate did not match expected hostname: hamao333333.2style.net. Certificate: {'subject': ((('commonName', 's8.gungunboo.com'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '03A23639827CCCC1A3DDECE146201E6608A5', 'notBefore': 'Apr 11 00:04:14 2023 GMT', 'notAfter': 'Jul 10 00:04:13 2023 GMT', 'subjectAltName': (('DNS', 's8.gungunboo.com'),), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# ERROR:downloader:Exception caught when downloading file https://hamao333333.2style.net/img/img_0281.jpg, error: HTTPSConnectionPool(host='hamao333333.2style.net', port=443): Max retries exceeded with url: /img/img_0281.jpg (Caused by SSLError(CertificateError("hostname 'hamao333333.2style.net' doesn't match 's8.gungunboo.com'"))), remaining retry times: 0
# ERROR:downloader:Response status code 404, file https://kuroneko-tedukuri.mimoza.jp/wp-content/uploads/2015/03/DSCF2271.jpg
# ERROR:downloader:Exception caught when downloading file https://www.ranger.ne.jp/images/material/item_XXL/A-54-m.jpg, error: HTTPSConnectionPool(host='www.ranger.ne.jp', port=443): Max retries exceeded with url: /images/material/item_XXL/A-54-m.jpg (Caused by SSLError(SSLError(1, '[SSL: WRONG_SIGNATURE_TYPE] wrong signature type (_ssl.c:1007)'))), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://www.ranger.ne.jp/images/material/item_XXL/A-54-m.jpg, error: HTTPSConnectionPool(host='www.ranger.ne.jp', port=443): Max retries exceeded with url: /images/material/item_XXL/A-54-m.jpg (Caused by SSLError(SSLError(1, '[SSL: WRONG_SIGNATURE_TYPE] wrong signature type (_ssl.c:1007)'))), remaining retry times: 1
# ERROR:downloader:Response status code 403, file https://cdn.snsimg.carview.co.jp/minkara/note/000/005/354/077/5354077/p4.jpg
# ERROR:downloader:Exception caught when downloading file https://www.ranger.ne.jp/images/material/item_XXL/A-54-m.jpg, error: HTTPSConnectionPool(host='www.ranger.ne.jp', port=443): Max retries exceeded with url: /images/material/item_XXL/A-54-m.jpg (Caused by SSLError(SSLError(1, '[SSL: WRONG_SIGNATURE_TYPE] wrong signature type (_ssl.c:1007)'))), remaining retry times: 0
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/8444101_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/1668908_3L1.jpg
# ERROR:downloader:Response status code 403, file https://cdn.snsimg.carview.co.jp/carlife/images/UserCarPat/2013893/p1.jpg
# ERROR:downloader:Response status code 403, file https://cdn.snsimg.carview.co.jp/minkara/userstorage/000/044/866/917/4c1ca46672.jpg
# ERROR:downloader:Response status code 404, file https://tshop.r10s.jp/tokyu-hands/cabinet/93/02/2401009987893-1.jpg
# ERROR:downloader:Response status code 404, file https://shop.r10s.jp/tokyu-hands/cabinet/78/03/4904140785178-1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/2925518_3L1.jpg
# ERROR:downloader:Response status code 403, file https://askul.c.yimg.jp/img/product/3L1/P696148_3L1.jpg
# ERROR:downloader:Response status code 403, file https://auctions.c.yimg.jp/images.auctions.yahoo.co.jp/image/dr000/auc0308/users/5b34f18ffeca3dedc8c5e879799e1574642fb73c/i-img700x700-1659340331rpahpi6645.jpg
# ERROR:downloader:Exception caught when downloading file https://www.intl-goods.co.jp/images/material/item_L/vinyltape.jpg, error: HTTPSConnectionPool(host='www.intl-goods.co.jp', port=443): Max retries exceeded with url: /images/material/item_L/vinyltape.jpg (Caused by SSLError(SSLError(1, '[SSL: WRONG_SIGNATURE_TYPE] wrong signature type (_ssl.c:1007)'))), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://www.intl-goods.co.jp/images/material/item_L/vinyltape.jpg, error: HTTPSConnectionPool(host='www.intl-goods.co.jp', port=443): Max retries exceeded with url: /images/material/item_L/vinyltape.jpg (Caused by SSLError(SSLError(1, '[SSL: WRONG_SIGNATURE_TYPE] wrong signature type (_ssl.c:1007)'))), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://www.intl-goods.co.jp/images/material/item_L/vinyltape.jpg, error: HTTPSConnectionPool(host='www.intl-goods.co.jp', port=443): Max retries exceeded with url: /images/material/item_L/vinyltape.jpg (Caused by SSLError(SSLError(1, '[SSL: WRONG_SIGNATURE_TYPE] wrong signature type (_ssl.c:1007)'))), remaining retry times: 0
# ERROR:downloader:Response status code 403, file https://cdn.snsimg.carview.co.jp/minkara/note/000/005/354/077/5354077/p4.jpg
# WARNING:urllib3.connection:Certificate did not match expected hostname: www.morikou.e-choshi.jp. Certificate: {'subject': ((('commonName', '*.e-choshi.jp'),),), 'issuer': ((('countryName', 'JP'),), (('organizationName', 'Japan Registry Services Co., Ltd.'),), (('commonName', 'JPRS Domain Validation Authority - G4'),)), 'version': 3, 'serialNumber': '5406AF8898525F044B412674DE1F8872', 'notBefore': 'Nov 30 01:01:12 2022 GMT', 'notAfter': 'Nov 30 14:59:59 2023 GMT', 'subjectAltName': (('DNS', '*.e-choshi.jp'), ('DNS', 'e-choshi.jp')), 'OCSP': ('http://dv.g4.ocsp.pubcert.jprs.jp',), 'caIssuers': ('http://repo.pubcert.jprs.jp/sppca/jprs/dvca_g4/JPRS_DVCA_G4_DER.cer',), 'crlDistributionPoints': ('http://repo.pubcert.jprs.jp/sppca/jprs/dvca_g4/fullcrl.crl',)}
# ERROR:downloader:Exception caught when downloading file https://www.morikou.e-choshi.jp/userimage/92_4_883_0.jpg, error: HTTPSConnectionPool(host='www.morikou.e-choshi.jp', port=443): Max retries exceeded with url: /userimage/92_4_883_0.jpg (Caused by SSLError(CertificateError("hostname 'www.morikou.e-choshi.jp' doesn't match either of '*.e-choshi.jp', 'e-choshi.jp'"))), remaining retry times: 2
# WARNING:urllib3.connection:Certificate did not match expected hostname: www.morikou.e-choshi.jp. Certificate: {'subject': ((('commonName', '*.e-choshi.jp'),),), 'issuer': ((('countryName', 'JP'),), (('organizationName', 'Japan Registry Services Co., Ltd.'),), (('commonName', 'JPRS Domain Validation Authority - G4'),)), 'version': 3, 'serialNumber': '5406AF8898525F044B412674DE1F8872', 'notBefore': 'Nov 30 01:01:12 2022 GMT', 'notAfter': 'Nov 30 14:59:59 2023 GMT', 'subjectAltName': (('DNS', '*.e-choshi.jp'), ('DNS', 'e-choshi.jp')), 'OCSP': ('http://dv.g4.ocsp.pubcert.jprs.jp',), 'caIssuers': ('http://repo.pubcert.jprs.jp/sppca/jprs/dvca_g4/JPRS_DVCA_G4_DER.cer',), 'crlDistributionPoints': ('http://repo.pubcert.jprs.jp/sppca/jprs/dvca_g4/fullcrl.crl',)}
# ERROR:downloader:Exception caught when downloading file https://www.morikou.e-choshi.jp/userimage/92_4_883_0.jpg, error: HTTPSConnectionPool(host='www.morikou.e-choshi.jp', port=443): Max retries exceeded with url: /userimage/92_4_883_0.jpg (Caused by SSLError(CertificateError("hostname 'www.morikou.e-choshi.jp' doesn't match either of '*.e-choshi.jp', 'e-choshi.jp'"))), remaining retry times: 1
# WARNING:urllib3.connection:Certificate did not match expected hostname: www.morikou.e-choshi.jp. Certificate: {'subject': ((('commonName', '*.e-choshi.jp'),),), 'issuer': ((('countryName', 'JP'),), (('organizationName', 'Japan Registry Services Co., Ltd.'),), (('commonName', 'JPRS Domain Validation Authority - G4'),)), 'version': 3, 'serialNumber': '5406AF8898525F044B412674DE1F8872', 'notBefore': 'Nov 30 01:01:12 2022 GMT', 'notAfter': 'Nov 30 14:59:59 2023 GMT', 'subjectAltName': (('DNS', '*.e-choshi.jp'), ('DNS', 'e-choshi.jp')), 'OCSP': ('http://dv.g4.ocsp.pubcert.jprs.jp',), 'caIssuers': ('http://repo.pubcert.jprs.jp/sppca/jprs/dvca_g4/JPRS_DVCA_G4_DER.cer',), 'crlDistributionPoints': ('http://repo.pubcert.jprs.jp/sppca/jprs/dvca_g4/fullcrl.crl',)}
# ERROR:downloader:Exception caught when downloading file https://www.morikou.e-choshi.jp/userimage/92_4_883_0.jpg, error: HTTPSConnectionPool(host='www.morikou.e-choshi.jp', port=443): Max retries exceeded with url: /userimage/92_4_883_0.jpg (Caused by SSLError(CertificateError("hostname 'www.morikou.e-choshi.jp' doesn't match either of '*.e-choshi.jp', 'e-choshi.jp'"))), remaining retry times: 0
#   adding: tape_paper/ (stored 0%)
#   adding: tape_paper/000029.jpg (deflated 4%)
#   adding: tape_paper/000108.jpg (deflated 10%)
#   adding: tape_paper/000020.jpg (deflated 1%)
#   adding: tape_paper/000113.jpg (deflated 14%)
#   adding: tape_paper/000046.jpg (deflated 1%)
#   adding: tape_paper/000100.jpg (deflated 7%)
#   adding: tape_paper/000079.jpg (deflated 0%)
#   adding: tape_paper/000030.jpg (deflated 1%)
#   adding: tape_paper/000097.jpg (deflated 6%)
#   adding: tape_paper/000002.jpg (deflated 1%)
#   adding: tape_paper/000012.jpg (deflated 4%)
#   adding: tape_paper/000085.jpg (deflated 8%)
#   adding: tape_paper/000009.jpg (deflated 1%)
#   adding: tape_paper/000052.jpg (deflated 0%)
#   adding: tape_paper/000043.jpg (deflated 1%)
#   adding: tape_paper/000034.jpg (deflated 0%)
#   adding: tape_paper/000004.jpg (deflated 1%)
#   adding: tape_paper/000066.jpg (deflated 21%)
#   adding: tape_paper/000038.jpg (deflated 0%)
#   adding: tape_paper/000116.jpg (deflated 1%)
#   adding: tape_paper/000059.jpg (deflated 0%)
#   adding: tape_paper/000023.jpg (deflated 8%)
#   adding: tape_paper/000068.jpg (deflated 6%)
#   adding: tape_paper/000082.jpg (deflated 18%)
#   adding: tape_paper/000114.jpg (deflated 0%)
#   adding: tape_paper/000050.jpg (deflated 5%)
#   adding: tape_paper/000102.jpg (deflated 2%)
#   adding: tape_paper/000065.jpg (deflated 1%)
#   adding: tape_paper/000049.jpg (deflated 26%)
#   adding: tape_paper/000035.jpg (deflated 8%)
#   adding: tape_paper/000021.jpg (deflated 2%)
#   adding: tape_vinyl/000007.jpg (deflated 4%)
#   adding: tape_vinyl/000087.jpg (deflated 1%)
#   adding: tape_vinyl/000111.jpg (deflated 6%)
#   adding: tape_vinyl/000076.jpg (deflated 3%)
#   adding: tape_vinyl/000036.jpg (deflated 11%)
#   adding: tape_vinyl/000086.jpg (deflated 9%)
#   adding: tape_vinyl/000042.jpg (deflated 10%)
#   adding: tape_vinyl/000069.jpg (deflated 12%)
#   adding: tape_vinyl/000061.jpg (deflated 2%)
#   adding: tape_vinyl/000092.jpg (deflated 3%)
#   adding: tape_vinyl/000026.jpg (deflated 0%)
#   adding: tape_vinyl/000093.jpg (deflated 0%)
#   adding: tape_vinyl/000073.jpg (deflated 5%)
#   adding: tape_vinyl/000045.jpg (deflated 2%)
#   adding: tape_vinyl/000064.jpg (deflated 7%)
#   adding: tape_vinyl/000022.jpg (deflated 2%)
#   adding: tape_vinyl/000077.jpg (deflated 1%)
#   adding: tape_vinyl/000013.jpg (deflated 0%)
#   adding: tape_vinyl/000060.jpg (deflated 0%)
#   adding: tape_vinyl/000014.jpg (deflated 9%)
#   adding: tape_vinyl/000018.jpg (deflated 3%)
#   adding: tape_vinyl/000105.jpg (deflated 0%)
#   adding: tape_vinyl/000106.jpg (deflated 0%)
#   adding: tape_vinyl/000084.jpg (deflated 6%)
#   adding: tape_vinyl/000031.jpg (deflated 2%)
#   adding: tape_vinyl/000032.jpg (deflated 0%)
#   adding: tape_vinyl/000047.jpg (deflated 2%)
#   adding: tape_vinyl/000055.jpg (deflated 32%)
#   adding: tape_vinyl/000089.jpg (deflated 0%)
#   adding: tape_vinyl/000017.jpg (deflated 2%)
#   adding: tape_vinyl/000090.jpg (deflated 2%)
#   adding: tape_vinyl/000044.jpg (deflated 4%)
#   adding: tape_vinyl/000094.jpg (deflated 3%)
#   adding: tape_vinyl/000040.jpg (deflated 0%)
#   adding: tape_vinyl/000003.jpg (deflated 5%)
#   adding: tape_vinyl/000095.jpg (deflated 0%)
#   adding: tape_vinyl/000067.jpg (deflated 15%)
#   adding: tape_vinyl/000109.jpg (deflated 0%)
#   adding: tape_vinyl/000054.jpg (deflated 4%)
#   adding: tape_vinyl/000081.jpg (deflated 0%)
#   adding: tape_vinyl/000010.jpg (deflated 5%)
#   adding: tape_vinyl/000058.jpg (deflated 3%)
#   adding: tape_vinyl/000115.jpg (deflated 3%)
#   adding: tape_vinyl/000011.jpg (deflated 4%)
#   adding: tape_vinyl/000008.jpg (deflated 13%)
#   adding: tape_vinyl/000015.jpg (deflated 1%)
#   adding: tape_vinyl/000024.jpg (deflated 1%)
#   adding: tape_vinyl/000028.jpg (deflated 2%)

# %% [markdown]
# ### 収集した画像の読み込み
#
# 画像をopencv (`cv2`) というモジュールで読み込みます。画像は`numpy`の`np.ndarray`という配列オブジェクトとして読み込まれます。
# `ndarray`で気にかけておくべきことは次の3つです。
# - 配列の次元 = ランク (`ndarray.ndim`)
# - 配列の形 (`ndarray.shape`)
# - 配列のデータ型 (`ndarray.dtype`)
#
# 一方で中身の個々の値に関しては、大きい配列ですと確認が難しいため、最大値や平均値など配列全体としての情報から期待している数値が入っているか推測することになります。
#
# <img src="https://qph.fs.quoracdn.net/main-qimg-30be20ab9458b5865b526d287b4fef9a" width="500" >
#
# 低次元の配列には名前がついています。
# - 0次元: スカラー
# - 1次元: ベクトル
# - 2次元: マトリックス
#
# これらを一般化した概念をテンソルと呼びます。

# %%
# ダウンロードした画像を全て同じ大きさにリサイズし、メモリに格納
import numpy as np
import cv2
from pathlib import Path  # ディスク上のファイル一覧を取得するなど、パスの操作に用いるモジュール

img_size = 64
imgs_cat = list()
imgs_dog = list()
imgs_rabit = list()

for img_list, img_dir in ((imgs_cat, class1_name), (imgs_dog, class2_name), (imgs_rabit, class3_name)):
  # 画像パス一つずつを処理
  for impath in Path(img_dir).iterdir():
    # 画像読み込み: cv2.imread()
    img = cv2.imread(str(impath))
    if img is None: continue
    # 画像リサイズ
    img = cv2.resize(img, (img_size, img_size))
    img_list.append(img)

# listをndarrayに変換
imgs_cat = np.array(imgs_cat)
imgs_dog = np.array(imgs_dog)
imgs_rabit = np.array(imgs_rabit)

# テンソルの情報を確認
print('imgs_cat.ndim =', imgs_cat.ndim)
print('imgs_cat.shape =', imgs_cat.shape)
print('imgs_cat.dtype =', imgs_cat.dtype)
print('')
print('imgs_dog.ndim =', imgs_dog.ndim)
print('imgs_dog.shape =', imgs_dog.shape)
print('imgs_dog.dtype =', imgs_dog.dtype)
print('')
print('imgs_rabit.ndim =', imgs_rabit.ndim)
print('imgs_rabit.shape =', imgs_rabit.shape)
print('imgs_rabit.dtype =', imgs_rabit.dtype)
# Out:
# imgs_cat.ndim = 4
# imgs_cat.shape = (116, 64, 64, 3)
# imgs_cat.dtype = uint8
#
# imgs_dog.ndim = 4
# imgs_dog.shape = (121, 64, 64, 3)
# imgs_dog.dtype = uint8
#
# imgs_rabit.ndim = 4
# imgs_rabit.shape = (120, 64, 64, 3)
# imgs_rabit.dtype = uint8

# %% [markdown]
# `cv2.imread()`関数で読み込んだ画像のデータ型は、デフォルトでは`np.uint8`という、符号なし（=マイナスを表現できない）8 bitの整数です。[0, 255]の範囲のみ表現可能です。
# `imgs_cat`は4次元配列で形が(n, 64, 64, 3)になっています。これは、最初の軸 (`axis = 0`) には画像の枚数nが、続く3つの次元には64 x 64 pixelの3チャネル (RGB) 画像が格納されているという意味になっています。
# (`cv2.imread()`で読み込んだ画像は、厳密にはチャネルの並びがBGRの順番になっています。)

# %% [markdown]
# ### 収集した画像の確認
#
# 読み込んだ画像をタイル状に並べて確認します

# %%
# 画像の一覧可視化関数
import math
import PIL

def tile_show(imgs, n_col=10):
  h, w = imgs[0].shape[:2]
  assert all([img.shape[:2] == (h, w) for img in imgs])
  n_row = math.ceil(len(imgs) / n_col)
  tile = np.zeros((h*n_row, w*n_col, 3), imgs[0].dtype)
  for i, img in enumerate(imgs):
    row = i // n_col
    col = i % n_col
    y1 = row * h
    y2 = (row+1) * h
    x1 = col * w
    x2 = (col+1) * w
    tile[y1:y2, x1:x2] = img
  
  if not tile.dtype == np.uint8:
    tile -= tile.min()
    tile /= tile.max()
    tile *= 255
    tile = np.clip(tile.astype(np.uint8), 0, 255)
  return PIL.Image.fromarray(tile[..., ::-1])

# %%
print(len(imgs_cat))
tile_show(imgs_cat)
# Out:
# 116
# <PIL.Image.Image image mode=RGB size=640x768 at 0x7F0803027F10>

# %%
print(len(imgs_dog))
tile_show(imgs_dog)
# Out:
# 121
# <PIL.Image.Image image mode=RGB size=640x832 at 0x7F0802EE87F0>

# %%
print(len(imgs_rabit))
tile_show(imgs_rabit)
# Out:
# 120
# <PIL.Image.Image image mode=RGB size=640x768 at 0x7F083B93EBC0>

# %% [markdown]
# ### 学習データ・テストデータの作成
#
# 収集した画像を学習用とテスト用（精度評価用）に分け、ラベル（正解）を付与する（猫=0、犬=1）。
# 今回は **二値分類** なので、変数1つに猫か犬かという意味を持たせることができる（変数が0に近ければ猫である確率が高く、1に近ければ犬である確率が高い）。
#
#
# 3クラス以上の分類 **多クラス分類** では、カテゴリの変数をone-hot encodingという手法でベクトルに変換してから用いることが一般的である。なお、二値分類でもone-hot表現は可能で、こちらの方がいい精度が出る（気がする）ので今回はこちらを使う。
#
# <img src="https://smart-hint.com/wp-content/uploads/2021/11/image-47.png" width="500"><a href="https://smart-hint.com/python/dummies/">src</a>
#
#
# また、画像処理では、入力画像を少数で[-1, 1]の範囲に正規化して用いることが多い。すなわち、`np.uint8`[0, 255]を`np.float32`[-1, 1]に変換する。
#
# 入力の画像とラベルは、次に作成するモデルの入出力とマッチするように作成する。

# %%
import tensorflow as tf

# 学習データとテストデータの作成
test_rate = 0.2
n_cat_test = int(len(imgs_cat) * test_rate)
n_dog_test = int(len(imgs_dog) * test_rate)
n_rabit_test = int(len(imgs_rabit) * test_rate)

cat_test, cat_train = imgs_cat[:n_cat_test], imgs_cat[n_cat_test:]
dog_test, dog_train = imgs_dog[:n_dog_test], imgs_dog[n_dog_test:]
rabit_test, rabit_train = imgs_rabit[:n_rabit_test], imgs_rabit[n_rabit_test:]

# ndarrayの結合, dtypeをfloat32に変更, [-1,1]に正規化
train_X = np.concatenate([cat_train, dog_train, rabit_train], axis=0)
train_X = train_X.astype(np.float32)
train_X = ((train_X / 255.) - 0.5) * 2
test_X = np.concatenate([cat_test, dog_test, rabit_test], axis=0)
test_X = test_X.astype(np.float32)
test_X = ((test_X / 255.) - 0.5) * 2

# 正規化の確認。train_Xに含まれる全画素の輝度のヒストグラム
plt.hist(train_X.flatten())

# ラベルを作成。猫=0、犬=1として設定
train_y = np.array([0.] * len(cat_train) + [1.] * len(dog_train) + [2.] * len(rabit_train)).astype(np.float32)
test_y = np.array([0.] * len(cat_test) + [1.] * len(dog_test) + [2.] * len(rabit_test)).astype(np.float32)
print(train_y.shape)

# one-hot encoding
train_y = tf.keras.utils.to_categorical(train_y, 3)
test_y = tf.keras.utils.to_categorical(test_y, 3)
print(train_y.shape)
# Out:
# (286,)
# (286, 3)

# %% [markdown]
# ### モデルの作成
#
# 今回はVGG16という畳み込みニューラルネットワークを用います。
# 有名なモデルはtensorflwoフレームワークに組み込まれており、呼び出すだけでモデルが使用できます。

# %%
from tensorflow.keras.applications import VGG16

model = VGG16(
    include_top=True, 
    weights=None, 
    input_shape=(img_size, img_size, 3), 
    classes=3,
    )
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 4096)              8392704
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 3)                 12291
#
# =================================================================
# Total params: 39,900,995
# Trainable params: 39,900,995
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#   `tf.keras.Model.summary()`メソッドでは、モデルの各レイヤーのテンソルの形が表示されます (`None`は数値が任意であることを示す) 。モデルを1つの大きな関数として考えた時、重要なのは入力と出力です。
# - input:  `input_5 (InputLayer)        [(None, 64, 64, 3)]`
# - output:   `predictions (Dense)         (None, 2)`
#
# このモデルは、「4次元テンソルを入力されると2次元テンソルを出力する関数」と言えます。

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (286, 64, 64, 3)
# (286, 3)

# %% [markdown]
# 学習データ画像`train_X`とinputのshape、正解ラベル`train_y`のとoutputのshapeが一致していることが確認できます。

# %% [markdown]
# #### ニューラルネットワーク
#
# <img src="https://www.esector.co.jp/bpa/img/A19-034.png" width="500">
# <a href="https://www.esector.co.jp/bpa/A19-034.html">src</a>
#
# ニューロンに対応する部分をノードなどと呼ぶ。たいてい1ノードだけで扱うことはなく、層のような構造に例えられるためレイヤーとも呼ばれる
#
# <img src="https://www.imagazine.co.jp/wp-content/uploads/2018/07/086-090_16ISno13_kiso_deep_zu003.jpg" width="500">
# <a href="https://www.imagazine.co.jp/%E7%95%B3%E3%81%BF%E8%BE%BC%E3%81%BF%E3%83%8D%E3%83%83%E3%83%88%E3%83%AF%E3%83%BC%E3%82%AF%E3%81%AE%E3%80%8C%E5%9F%BA%E7%A4%8E%E3%81%AE%E5%9F%BA%E7%A4%8E%E3%80%8D%E3%82%92%E7%90%86%E8%A7%A3%E3%81%99/">src</a>
#
# 畳み込みニューラルネットワーク（CNN）は、神経細胞の発火のルールを、画像の部分領域をベースにしたという点で、人間の視覚処理により近い構造を模していると考えることができる。

# %% [markdown]
# #### 畳み込み処理
#
# <img src="https://axa.biopapyrus.jp/media/CNN_Conv3.png" width="500"><a href="https://axa.biopapyrus.jp/deep-learning/cnn/convolution.html">src</a>
#
# 中央の3x3の配列をfilter, kernel, windowなどと呼ぶ。畳み込みは特定のパターン（模様）を抽出する操作だと考えることもでき、フィルターの内容がパターンを決定する。CNNでは、フィルターの中身を学習によって更新し、学習がうまく進むと画像内の特徴量（猫らしさ、犬らしさの指標になる模様など）が抽出できるようになる。
#
#
# <img src="https://i.stack.imgur.com/wrxLE.png" width="500"><a href="http://web.pdx.edu/~jduh/courses/Archive/geog481w07/Students/Ludwig_ImageConvolution.pdf">src</a>
# カーネルの違いによる畳み込み効果の例

# %% [markdown]
# ### モデルの学習

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(train_X, train_y, epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 9/9 [==============================] - 27s 240ms/step - loss: 1.0986 - accuracy: 0.2902
# Epoch 2/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0982 - accuracy: 0.3741
# Epoch 3/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0976 - accuracy: 0.3357
# Epoch 4/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0965 - accuracy: 0.3357
# Epoch 5/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0946 - accuracy: 0.3357
# Epoch 6/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0903 - accuracy: 0.3357
# Epoch 7/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0838 - accuracy: 0.3531
# Epoch 8/30
# 9/9 [==============================] - 0s 55ms/step - loss: 1.0762 - accuracy: 0.4056
# Epoch 9/30
# 9/9 [==============================] - 1s 56ms/step - loss: 1.0682 - accuracy: 0.3986
# Epoch 10/30
# 9/9 [==============================] - 0s 56ms/step - loss: 1.0573 - accuracy: 0.4371
# Epoch 11/30
# 9/9 [==============================] - 0s 55ms/step - loss: 1.0503 - accuracy: 0.4266
# Epoch 12/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0485 - accuracy: 0.4545
# Epoch 13/30
# 9/9 [==============================] - 0s 55ms/step - loss: 1.0462 - accuracy: 0.4301
# Epoch 14/30
# 9/9 [==============================] - 0s 55ms/step - loss: 1.0483 - accuracy: 0.4056
# Epoch 15/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0342 - accuracy: 0.4476
# Epoch 16/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0355 - accuracy: 0.4510
# Epoch 17/30
# 9/9 [==============================] - 0s 55ms/step - loss: 1.0310 - accuracy: 0.4371
# Epoch 18/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0503 - accuracy: 0.3916
# Epoch 19/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0263 - accuracy: 0.4685
# Epoch 20/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0185 - accuracy: 0.4790
# Epoch 21/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0096 - accuracy: 0.4650
# Epoch 22/30
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0008 - accuracy: 0.5035
# Epoch 23/30
# 9/9 [==============================] - 0s 55ms/step - loss: 1.0020 - accuracy: 0.4755
# Epoch 24/30
# 9/9 [==============================] - 0s 55ms/step - loss: 0.9932 - accuracy: 0.4790
# Epoch 25/30
# 9/9 [==============================] - 0s 55ms/step - loss: 0.9902 - accuracy: 0.5070
# Epoch 26/30
# 9/9 [==============================] - 0s 54ms/step - loss: 0.9901 - accuracy: 0.4930
# Epoch 27/30
# 9/9 [==============================] - 0s 55ms/step - loss: 0.9759 - accuracy: 0.5455
# Epoch 28/30
# 9/9 [==============================] - 0s 55ms/step - loss: 0.9650 - accuracy: 0.5175
# Epoch 29/30
# 9/9 [==============================] - 0s 54ms/step - loss: 0.9673 - accuracy: 0.5070
# Epoch 30/30
# 9/9 [==============================] - 0s 54ms/step - loss: 0.9573 - accuracy: 0.5420

# %%
# 学習過程の可視化
fig, ax1 = plt.subplots()
ax1.plot(history.history['loss'], label='(left) loss')
ax1.set_xlabel('epoch')
ax1.set_ylabel('loss')
ax2 = ax1.twinx()
ax2.plot(history.history['accuracy'], label='(right) accuracy', c='r')
ax2.set_ylabel('accuracy')
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2, loc='center left')
plt.show()

# %% [markdown]
# ### 学習したモデルのテスト
#
# テストデータから1枚、画像を取り出して学習したモデルに適用してみる。
# outputは`tf.Tensor`という型であり、`tf.Tensor.numpy()`メソッドによりnumpyの数値として情報を取り出すことができる。

# %%
# [-1,1]に正規化されている画像を表示する関数
def show_standardized_img(img):
  img -= img.min()
  img /= img.max()
  img *= 255
  img = np.clip(img, 0, 255).astype(np.uint8)
  return PIL.Image.fromarray(img[..., ::-1])

# %%
import random
ix = random.randint(0, len(test_X)-1)
show_standardized_img(test_X[ix])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F0711269A50>

# %%
output = model(test_X[ix][np.newaxis], training=False)
print(output)
print(output.numpy())
# Out:
# tf.Tensor([[1.0000000e+00 0.0000000e+00 3.7738915e-36]], shape=(1, 3), dtype=float32)
# [[1.0000000e+00 0.0000000e+00 3.7738915e-36]]

# %% [markdown]
# `output`の`shape`は (1, 2) となっているが、これは実質的には長さ2のベクトルであり、「猫である確率」と「犬である確率」の順で格納されている。

# %%
vector = output.numpy()[0]
print('猫である確率:', f'{vector[0]:.3f}')
print('犬である確率:', f'{vector[1]:.3f}')
print('うさぎである確率:', f'{vector[2]:.3f}')
# Out:
# 猫である確率: 1.000
# 犬である確率: 0.000
# うさぎである確率: 0.000

# %% [markdown]
# テスト画像の表示とモデルの出力を関数でひとまとめにし、何度か実行してモデルの性能の感覚をつかむ。

# %%
def sample_and_predict(model, X):
  ix = random.randint(0, len(X)-1)
  output = model(X[ix][np.newaxis], training=False)
  vector = output.numpy()[0]
  print('ガムテープ紙製である確率:', f'{vector[0]:.3f}')
  print('ガムテープ布製である確率:', f'{vector[1]:.3f}')
  print('ガムテープビニール製である確率:', f'{vector[2]:.3f}')
  return show_standardized_img(X[ix])

# %%
sample_and_predict(model, test_X)
# Out:
# ガムテープ紙製である確率: 0.060
# ガムテープ布製である確率: 0.465
# ガムテープビニール製である確率: 0.475
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F0705DEA6E0>

# %% [markdown]
# ### 精度評価
#
# 混合行列 (confusion matrix) を作成する。クラス分類の問題では、正解率や感度など、1つの数字で表現される指標がいくつか存在するが、指標それぞれが見える部分と見えない部分を持つ。
#
# confusion matrixは全ての指標の元になる行列であるので、これさえ載せておけば漏れなく全体を把握することができる。
#
# 今回は「猫と判定すること」を陽性 (positive) として考える。
#
# <img src="https://www.naukri.com/learning/articles/wp-content/uploads/sites/11/2022/03/Confusion-matrix-1.png" width="500"><a href="https://www.naukri.com/learning/articles/web-stories/confusion-matrix-in-machine-learning/">src</a>

# %%
# confusion matrixの算出
true = np.argmax(test_y, axis=-1)
test_y_hat = model.predict(test_X)
pred = np.argmax(test_y_hat, axis=-1)

print(len(test_X))

confmat = tf.math.confusion_matrix(true, pred).numpy()
confmat
# Out:
# 3/3 [==============================] - 1s 184ms/step
# 71
# array([[ 9,  7,  7],
#        [10,  9,  5],
#        [ 6,  9,  9]], dtype=int32)

# %% [markdown]
# confusion matrixは包括的な情報ではあるものの、ぱっと見ではよくわからないので指標も計算する。
# ポイント：別名があったり日本語訳がしっくりこなかったりわかりにくい。覚えるというよりは意味合いを把握することが大事
#
# <img src="https://cdn-ssl-devio-img.classmethod.jp/wp-content/uploads/2015/08/Untitled.png"><a href="https://dev.classmethod.jp/articles/aml-evaluation-measures/">src</a>
#
# - 正解率 Accuracy
# $ \frac{TP + TN}{TP + FP + FN + TN} $
#
# - 感度 Sensitivity (Recall, True Positive Rate 再現率 検出率 真陽性率)
# $ \frac{TP}{TP + FN} $
# 疾病検査を例にすると、その検査が疾病をとらえる「感度・検出率」となる。(検査で病気と分かった人 / 実際に病気の人)
#
#
# - 特異度 Specificity (True Negative Rate 真陰性率)
# $ \frac{TN}{FP + TN} $
# 検査で言えば、検査で陰性だった人 / 実際に陰性の人
#
# - 陽性的中率 Positive Predictive Value (Precision 適合度 精度)
# $ \frac{TP}{TP + FP} $
# 「陽性適中率が高い」とは、「検査結果が陽性と判定された場合に、真の陽性（有病者）である確率が高い」という意味。
#
#
# 他にも山ほどあります [wikipedia](https://en.wikipedia.org/wiki/Evaluation_of_binary_classifiers)

# %%
[[TP_paper, No_fabric_paper, No_vinyl_paper], 
 [No_paper_fabric, TP_fabric, No_vinyl_fabric],
 [No_paper_vinyl, No_fabric_vinyl, TP_vinyl]] = confmat
 
print(TP_paper, No_fabric_paper, No_vinyl_paper)

accuracy = (TP_paper + TP_fabric + TP_vinyl) / (TP_paper + No_fabric_paper + No_vinyl_paper + 
                                                No_paper_fabric + TP_fabric + No_vinyl_fabric +
                                                No_paper_vinyl + No_fabric_vinyl + TP_vinyl)

#ガムテープ　紙製
print("paper")
sensitivity = TP_paper / (TP_paper + No_fabric_paper + No_vinyl_paper)
specificity = TP_paper / (TP_paper + No_paper_fabric + No_paper_vinyl)
#precision = TP / (TP + FP)
print("")

print('正解率', accuracy)
print('感度', sensitivity)
print('特異度', specificity)
#print('陽性的中率', precision)

from sklearn.metrics import confusion_matrix
# Out:
# 9 7 7
# paper
#
# 正解率 0.38028169014084506
# 感度 0.391304347826087
# 特異度 0.36

# %% [markdown]
# ### 学習モデルの実利用
#
# 学習モデルはデータセット外の実データに適用して初めて役立ちます。
# ここでは例として、画像URLを受け取ると猫か犬か判定してくれるwebサービスを想定します。
#
# (実際のサービス例：[Google Lens](https://lens.google/intl/ja/#:~:text=%E6%A4%8D%E7%89%A9%E3%82%84%E5%8B%95%E7%89%A9,%E7%A2%BA%E8%AA%8D%E3%81%A7%E3%81%8D%E3%81%BE%E3%81%99%E3%80%82))

# %%
# urlから画像を読みこむcv2u.urlread()を使用するためパッケージをインストール
# !pip install python-opencv-utils
import cv2u

# %%
#@title 犬猫画像判定サービス { run: "auto", vertical-output: true }

labels = {0: 'ネコ', 1: 'イヌ'}

URL = '' #@param {type:"string"}
try:
  img = cv2u.urlread(URL)
except ValueError:
  img = None

if img is None:
  if URL:
    print('!!! 画像が見つかりません !!!')

else:
  X = cv2.resize(img, (img_size, img_size))
  X = ((X.astype(np.float32) / 255.) - 0.5) * 2
  X = X[np.newaxis]
  y = model.predict(X)
  label = labels[np.argmax(y[0])]
  score = np.max(y) * 100
  print(f'これは {score: .1f}% 「{label}」 です！')
  plt.imshow(img[..., ::-1])
  plt.axis("off")
  plt.show()

# %% [markdown]
# ### より良い精度を目指して
#
# - データセットの量を増やす
# 今回のデモでは各クラスの画像の最大量は200枚としました。一般的には学習量を増やせば精度が向上する傾向にあります。
#
# - 質の高いデータセットの準備
# 画像データを可視化するとわかりますが、スクレイピングで得られた画像には全く関係ないものがある程度含まれます。これらを取り除き、質の高いデータセットを構築することが精度向上につながります。
#
# - データの水増し (データ拡張、Data Augmentation)
# データセットの量を増やすのは人力が多く骨が折れます。水増しの手法では、1枚の画像を疑似的に増幅し、枚数が増えたように見せかけます。
# <img src="https://qph.fs.quoracdn.net/main-qimg-7565e09ecc4a93604b9c26c8c2a89bf9-pjlq" width="500"><a href="https://www.quora.com/What-is-data-augmentation-in-CNN">src</a>
#
# - モデルの変更
# VGG16は2014年に開発されたモデルで古いため、よりよいモデルが多く開発されています。
# 代表的なもの: ResNet (2015), EfficientNet (2019)
